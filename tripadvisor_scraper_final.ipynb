# %% [markdown]
# **Tripadvisor 국내 투어 프로그램 리뷰 데이터 분석을 통한 랜선투어 상품 개발**
# - 목적 : Tours & Tickets 메뉴에 등록된 국내 투어 프로그램 리뷰 데이터를 분석하여 오프라인 경험을 최대한 살릴 수 있는 랜선투어 상품 개발
# - 단계 :<br>
# 1) 리뷰수, 평균평점을 기준으로 Top N 인기 프로그램 선정<br>
# 2) 선정 프로그램의 리뷰 데이터 크롤링<br>
# 3) 리뷰 내용을 평점별로 구분하여 분석 (높은 평점 vs 낮은 평점)<br>
# 4) 분석 내용을 기반으로 국내 랜선투어 프로그램 개발

# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from tqdm import tqdm

pd.set_option('display.max_columns', None)
pd.set_option("display.max_colwidth", -1)
# Out:
# <ipython-input-1-8d3e13b3571c>:8: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option("display.max_colwidth", -1)

# %%
# Importing tour title & url file (separately scraped)
df_title = pd.read_excel('tour_titles_url_korea.xlsx').drop(['Unnamed: 0', 'tour_location'], axis = 1)
df_title['tour_title'] = df_title['tour_title'].str.replace(' ', '_').str.replace(':','').str.replace('&','_').str.replace('-','_')\
.str.replace('(','').str.replace(')','').str.replace('___','_').str.replace('__','_')
df_title
# Out:
#                                                                          tour_title  \
# 0    Seoul_Private_Flexible_Adventure_Tour
# 1    Korean_History_Heritage_Tour
# 2    Fully_Customizable_Private_Tour_From_Seoul_to_Gyeonggi
# 3    Half_Day_Korean_DMZ_Tour_from_Seoul
# 4    Korean_Demilitarized_Zone_DMZ_Half_Day_Tour_from_Seoul
# ..                                                      ...
# 140  Suwon_Hwaseong_Fortress_and_Korean_Folk_Village_Day_Tour_from_Seoul
# 141  Korean_Palace_and_Temple_Tour_in_Seoul_Gyeongbokgung_Palace_and_Jogyesa_Temple
# 142  Korean_Folk_Village
# 143  History_and_Culture_Tour
# 144  Gyeongbokgung_Palace_Hanbok_Rental_Experience_in_Seoul
#
#                                                                                                                          tour_url
# 0    AttractionProductReview-g294197-d12521956-Seoul_Private_Flexible_Adventure_Tour-Seoul
# 1    AttractionProductReview-g294197-d15883739-Korean_History_Heritage_Tour-Seoul
# 2    AttractionProductReview-g294197-d12649287-Fully_Customizable_Private_Tour_From_Seoul_to_Gyeonggi-Seoul
# 3    AttractionProductReview-g294197-d11989360-Half_Day_Korean_DMZ_Tour_from_Seoul-Seoul
# 4    AttractionProductReview-g294197-d11454650-Korean_Demilitarized_Zone_DMZ_Half_Day_Tour_from_Seoul-Seoul
# ..                                                                                                      ...
# 140  AttractionProductReview-g294197-d11461630-Suwon_Hwaseong_Fortress_and_Korean_Folk_Village_Day_Tour_from_Seoul-Seoul
# 141  AttractionProductReview-g294197-d12463701-Korean_Palace_and_Temple_Tour_in_Seoul_Gyeongbokgung_Palace_and_Jogyesa_Temple-Seo
# 142  AttractionProductReview-g294197-d13159855-Korean_Folk_Village-Seoul
# 143  AttractionProductReview-g294197-d20232226-History_and_Culture_Tour-Seoul
# 144  AttractionProductReview-g294197-d12878495-Gyeongbokgung_Palace_Hanbok_Rental_Experience_in_Seoul-Seoul
#
# [145 rows x 2 columns]

# %%
df_title = df_title[107:]
df_title
# Out:
#                                                                          tour_title  \
# 107  Secret_Food_Tours_Seoul_w_Private_Tour_Option
# 108  Private_Day_Trip_to_Seoraksan_National_Park
# 109  Ganghwa_Island_Full_day_private_tour
# 110  Full_Day_Essential_Jeju_Island_Private_tour_for_West_Course
# 111  Hanbok_Photoshoot_in_Seoul
# 112  Suwon_Hwaseong_Fortress_Small_Group_Morning_Tour_from_Seoul
# 113  Private_Day_Trip_to_Korean_Folk_Village_and_Hwaseong_Fortress
# 114  Hanbok_Photo_Shooting_SnapStudio_Gyeongbokgung_Palace_Hanbok_Rental,_Make_up
# 115  VIP_Brompton_Bike_Food_Tour_with_Car_Pick_Up_Service
# 116  Private_Group_Day_Trip_to_Seongmodo_Island_and_Ganghwa_Island
# 117  Pyeongchang_Private_Day_Trip_from_Seoul
# 118  Full_day_Customizable_Private_Seoul_Highlight_Tour_with_Hanbok_Experience
# 119  Serpent's_Tail_Half_Day_Canyoning_Tour_Gapyeong,_close_to_Seoul
# 120  Korean_Demilitarized_Zone_and_N_Seoul_Tower_Private_Tour
# 121  Korean_Food_Walking_Tour_with_BBQ_Lunch
# 122  Private_Gyeongju_tour_including_Seokguram,_Bulguksa_and_Tomb_park_from_Busan
# 123  Nami_Island_and_Petite_France_with_The_Garden_of_Morning_Calm_One_Day_Tour
# 124  Full_Day_Small_Group_Royal_Palace_and_Seoul_Tour
# 125  Jisan_Forest_Ski_Resort_from_Seoul_with_Ski_or_Sledding_Options
# 126  Best_of_Seoul_Tour_in_the_Afternoon
# 127  Private_Full_Day_Tour_to_Mt_Seorak_and_East_Sea
# 128  Best_of_Seoul_Tour_in_the_Afternoon
# 129  Gyeongju_Small_Group_One_Day_Tour_from_Busan_Max_7
# 130  Small_Group_2_Hour_Noryangjin_Fish_Market_Tasting_Walking_Tour
# 131  Markets_of_Seoul_Korean_Markets_and_City_Sightseeing_Tour
# 132  Royal_palace_and_Korean_Food_Half_Day_Walking_Tour
# 133  5D4N_Korea_Cultural_Heritage_immersion_Private_Tour
# 134  Full_Day_NO_SHOPPING_DMZ_Tour_starting_9_00AM
# 135  Private_Palace_Photo_Shoot_in_Seoul_with_a_Photographer
# 136  Modern_and_Contemporary_of_Seoul_tour
# 137  Winter_8_days_Ski_Jeju_Busan_Mt_Seorak_Seoul_on_the_end_Nov_to_Jan
# 138  Insadong_Gyeongbok_Palace_Hanok_Village_Gwangjang_Market_Korea_Day_Tour
# 139  Korea_by_LocalGood_Morning_Seoul,_hidden_Alley_and_Korea_Craft_Wine_experience
# 140  Suwon_Hwaseong_Fortress_and_Korean_Folk_Village_Day_Tour_from_Seoul
# 141  Korean_Palace_and_Temple_Tour_in_Seoul_Gyeongbokgung_Palace_and_Jogyesa_Temple
# 142  Korean_Folk_Village
# 143  History_and_Culture_Tour
# 144  Gyeongbokgung_Palace_Hanbok_Rental_Experience_in_Seoul
#
#                                                                                                                          tour_url
# 107  AttractionProductReview-g294197-d17597945-Secret_Food_Tours_Seoul_w_Private_Tour_Option-Seoul
# 108  AttractionProductReview-g294197-d12968517-Private_Day_Trip_to_Seoraksan_National_Park-Seoul
# 109  AttractionProductReview-g297889-d16823242-Ganghwa_Island_Full_day_private_tour-Incheon
# 110  AttractionProductReview-g297885-d16654477-Full_Day_Essential_Jeju_Island_Private_tour_for_West_Course-Jeju_Jeju_Island
# 111  AttractionProductReview-g294197-d11484280-Hanbok_Photoshoot_in_Seoul-Seoul
# 112  AttractionProductReview-g294197-d11464111-Suwon_Hwaseong_Fortress_Small_Group_Morning_Tour_from_Seoul-Seoul
# 113  AttractionProductReview-g294197-d12968516-Private_Day_Trip_to_Korean_Folk_Village_and_Hwaseong_Fortress-Seoul
# 114  AttractionProductReview-g294197-d17773425-Hanbok_Photo_Shooting_Snap_Studio_Gyeongbokgung_Palace_Hanbok_Rental_Make_up-Seoul
# 115  AttractionProductReview-g294197-d16795119-VIP_Brompton_Bike_Food_Tour_with_Car_Pick_Up_Service-Seoul
# 116  AttractionProductReview-g294197-d12471528-Private_Group_Day_Trip_to_Seongmodo_Island_and_Ganghwa_Island-Seoul
# 117  AttractionProductReview-g294197-d11915684-Pyeongchang_Private_Day_Trip_from_Seoul-Seoul
# 118  AttractionProductReview-g294197-d15559893-Full_day_Customizable_Private_Seoul_Highlight_Tour_with_Hanbok_Experience-Seoul
# 119  AttractionProductReview-g2024864-d17743849-Serpent_s_Tail_Half_Day_Canyoning_Tour_Gapyeong_close_to_Seoul-Gapyeong_gun_Gyeon
# 120  AttractionProductReview-g294197-d11475401-Korean_Demilitarized_Zone_and_N_Seoul_Tower_Private_Tour-Seoul
# 121  AttractionProductReview-g294197-d11452117-Korean_Food_Walking_Tour_with_BBQ_Lunch-Seoul
# 122  AttractionProductReview-g297884-d11454328-Private_Gyeongju_tour_including_Seokguram_Bulguksa_and_Tomb_park_from_Busan-Busan
# 123  AttractionProductReview-g294197-d15342445-Nami_Island_and_Petite_France_with_The_Garden_of_Morning_Calm_One_Day_Tour-Seoul
# 124  AttractionProductReview-g294197-d11989250-Full_Day_Small_Group_Royal_Palace_and_Seoul_Tour-Seoul
# 125  AttractionProductReview-g1872665-d11992413-Jisan_Forest_Ski_Resort_from_Seoul_with_Ski_or_Sledding_Options-Paju_Gyeonggi_do
# 126  AttractionProductReview-g294197-d14080994-Best_of_Seoul_Tour_in_the_Afternoon-Seoul
# 127  AttractionProductReview-g294197-d13275613-Private_Full_Day_Tour_to_Mt_Seorak_and_East_Sea-Seoul
# 128  AttractionProductReview-g294197-d14080994-Best_of_Seoul_Tour_in_the_Afternoon-Seoul
# 129  AttractionProductReview-g297884-d17555167-Gyeongju_Small_Group_One_Day_Tour_from_Busan_Max_7-Busan
# 130  AttractionProductReview-g294197-d12720398-Small_Group_2_Hour_Noryangjin_Fish_Market_Tasting_Walking_Tour-Seoul
# 131  AttractionProductReview-g294197-d11457684-Markets_of_Seoul_Korean_Markets_and_City_Sightseeing_Tour-Seoul
# 132  AttractionProductReview-g294197-d12971123-Royal_palace_and_Korean_Food_Half_Day_Walking_Tour-Seoul
# 133  AttractionProductReview-g294197-d15526727-5D4N_Korea_Cultural_Heritage_immersion_Private_Tour-Seoul
# 134  AttractionProductReview-g294197-d17699664-Full_Day_NO_SHOPPING_DMZ_Tour_starting_9_00AM-Seoul
# 135  AttractionProductReview-g294197-d19218987-Private_Palace_Photo_Shoot_in_Seoul_with_a_Photographer-Seoul
# 136  AttractionProductReview-g294197-d15689502-Modern_and_Contemporary_of_Seoul_tour-Seoul
# 137  AttractionProductReview-g297884-d16655076-Winter_8_days_Ski_Jeju_Busan_Mt_Seorak_Seoul_on_the_end_Nov_to_Jan-Busan
# 138  AttractionProductReview-g294197-d17525702-Insadong_Gyeongbok_Palace_Hanok_Village_Gwangjang_Market_Korea_Day_Tour-Seoul
# 139  AttractionProductReview-g294197-d20045700-Korea_by_Local_Good_Morning_Seoul_hidden_Alley_and_Korea_Craft_Wine_experience-Seo
# 140  AttractionProductReview-g294197-d11461630-Suwon_Hwaseong_Fortress_and_Korean_Folk_Village_Day_Tour_from_Seoul-Seoul
# 141  AttractionProductReview-g294197-d12463701-Korean_Palace_and_Temple_Tour_in_Seoul_Gyeongbokgung_Palace_and_Jogyesa_Temple-Seo
# 142  AttractionProductReview-g294197-d13159855-Korean_Folk_Village-Seoul
# 143  AttractionProductReview-g294197-d20232226-History_and_Culture_Tour-Seoul
# 144  AttractionProductReview-g294197-d12878495-Gyeongbokgung_Palace_Hanbok_Rental_Experience_in_Seoul-Seoul

# %%
# Opening Chrome web driver
driver = webdriver.Chrome('./chromedriver.exe')

# %%
tour_url = df_title['tour_url'].tolist()
tour_title = df_title['tour_title'].tolist()

# %%
def tour_search(program):
    '''Getting tour page url for tour programs'''
    url = f'https://www.tripadvisor.com/{program}.html'
    return url

def get_reviews(driver):
    '''Scraping review contents (title, comment, score)'''
    
    # Clicking 'read more' for review comments (5 items per page)
    try:
        driver.find_element_by_xpath("//div[@data-automation='reviewReadMoreCTA_0']").click()
        time.sleep(0.1)
        driver.find_element_by_xpath("//div[@data-automation='reviewReadMoreCTA_1']").click()
        time.sleep(0.1)
        driver.find_element_by_xpath("//div[@data-automation='reviewReadMoreCTA_2']").click()
        time.sleep(0.1)
        driver.find_element_by_xpath("//div[@data-automation='reviewReadMoreCTA_3']").click()
        time.sleep(0.1)
        driver.find_element_by_xpath("//div[@data-automation='reviewReadMoreCTA_4']").click()
        time.sleep(0.1)
        
    except:
        pass
    
    # Getting page source and parsing with BeautifulSoup
    results = driver.page_source
    soup = BeautifulSoup(results, 'lxml')
    review_pg_open = soup.select_one('[data-automation = "reviewList"]')

    result_pg = []
    
    for review in review_pg_open:
        # Tour title, review title, review comment, review date, trip type
        tour_title = soup.select('span.IKwHbf8J')[0].text
        review_title = review.select('div._2cigFICy')[0].text
        review_comment = review.select('q._2vmgOjMl > span')[0].text
        
        temp_date = review.select('div._30IBqsJg > span')
        try:
            if len(temp_date[0].text) > 0:
                review_date = temp_date[0].text
        except:
            review_date = ''

        # Review score
        path = review.find_all('path')
        score = 0
        for s in range(0,5):
            onclick = path[s].attrs['d']
            if onclick == 'M 12 0C5.388 0 0 5.388 0 12s5.388 12 12 12 12-5.38 12-12c0-6.612-5.38-12-12-12zm0 2a9.983 9.983 0 019.995 10 10 10 0 01-10 10A10 10 0 012 12 10 10 0 0112 2z':
                score += 0
            else :
                score += 1
            review_score = score
        
        # Trip type
        temp_type = review.findAll('div', {'class': '_20I-kAyv'})
        try:
            if len(temp_type[0].text) > 0:
                trip_type = temp_type[0].text
        except:
            trip_type = ''
        
        result = [tour_title, review_title, review_comment, review_date, review_score, trip_type]
        result_pg.append(result)
    
    df = pd.DataFrame(result_pg)
    df.columns = [['tour_title', 'review_title', 'review_comment', 'review_date', 'review_score', 'trip_type']]
    
    return df

def next_reviews(driver):
    '''Scraping information through get_reviews function and moving to next page'''
    result_all_pg = pd.DataFrame()
    
    for page in range(0,70):
        pg_review = get_reviews(driver)
        result_all_pg = pd.concat([result_all_pg, pg_review], axis = 0).reset_index(drop=True)
        print(f'{page} page done')
        
        try:
            driver.find_element_by_xpath("//a[@data-automation='pageLink_next']").click()
            time.sleep(3)
            page += 1
            
        except:
            break
            
    return result_all_pg

# %%
review_all_tours = pd.DataFrame()

for i in zip(tour_url, tour_title):
    url = tour_search(i[0])
    driver.get(url)
    driver.implicitly_wait(10)
    time.sleep(3)
    
    review = next_reviews(driver)
    
    review_all_tours = pd.concat([review_all_tours, review], axis = 0).reset_index(drop=True)
    review.to_excel(f'./t_scraped/{i[1]}_scored.xlsx')
    print(f'"{i[1]}" done')
# Out:
# 0 page done
# 1 page done
# 2 page done
# 3 page done
# 4 page done
# 5 page done
# "Secret_Food_Tours_Seoul_w_Private_Tour_Option" done
# 0 page done
# 1 page done
# "Private_Day_Trip_to_Seoraksan_National_Park" done
# 0 page done
# "Ganghwa_Island_Full_day_private_tour" done
# 0 page done
# "Full_Day_Essential_Jeju_Island_Private_tour_for_West_Course" done
# 0 page done
# 1 page done
# "Hanbok_Photoshoot_in_Seoul" done
# 0 page done
# "Suwon_Hwaseong_Fortress_Small_Group_Morning_Tour_from_Seoul" done
# 0 page done
# "Private_Day_Trip_to_Korean_Folk_Village_and_Hwaseong_Fortress" done
# 0 page done
# 1 page done
# 2 page done
# 3 page done
# "Hanbok_Photo_Shooting_SnapStudio_Gyeongbokgung_Palace_Hanbok_Rental,_Make_up" done
# 0 page done
# "VIP_Brompton_Bike_Food_Tour_with_Car_Pick_Up_Service" done
# 0 page done
# "Private_Group_Day_Trip_to_Seongmodo_Island_and_Ganghwa_Island" done
# 0 page done
# "Pyeongchang_Private_Day_Trip_from_Seoul" done
# 0 page done
# 1 page done
# 2 page done
# 3 page done
# "Full_day_Customizable_Private_Seoul_Highlight_Tour_with_Hanbok_Experience" done
# 0 page done
# "Serpent's_Tail_Half_Day_Canyoning_Tour_Gapyeong,_close_to_Seoul" done
# 0 page done
# 1 page done
# 2 page done
# "Korean_Demilitarized_Zone_and_N_Seoul_Tower_Private_Tour" done
# 0 page done
# 1 page done
# 2 page done
# 3 page done
# "Korean_Food_Walking_Tour_with_BBQ_Lunch" done
# 0 page done
# "Private_Gyeongju_tour_including_Seokguram,_Bulguksa_and_Tomb_park_from_Busan" done
# 0 page done
# "Nami_Island_and_Petite_France_with_The_Garden_of_Morning_Calm_One_Day_Tour" done
# 0 page done
# 1 page done
# 2 page done
# 3 page done
# "Full_Day_Small_Group_Royal_Palace_and_Seoul_Tour" done
# 0 page done
# 1 page done
# 2 page done
# 3 page done
# 4 page done
# "Jisan_Forest_Ski_Resort_from_Seoul_with_Ski_or_Sledding_Options" done
# 0 page done
# 1 page done
# "Best_of_Seoul_Tour_in_the_Afternoon" done
# 0 page done
# 1 page done
# 2 page done
# 3 page done
# "Private_Full_Day_Tour_to_Mt_Seorak_and_East_Sea" done
# 0 page done
# 1 page done
# "Best_of_Seoul_Tour_in_the_Afternoon" done
# 0 page done
# 1 page done
# 2 page done
# 3 page done
# 4 page done
# "Gyeongju_Small_Group_One_Day_Tour_from_Busan_Max_7" done
# 0 page done
# 1 page done
# 2 page done
# "Small_Group_2_Hour_Noryangjin_Fish_Market_Tasting_Walking_Tour" done
# 0 page done
# "Markets_of_Seoul_Korean_Markets_and_City_Sightseeing_Tour" done
# 0 page done
# "Royal_palace_and_Korean_Food_Half_Day_Walking_Tour" done
# 0 page done
# "5D4N_Korea_Cultural_Heritage_immersion_Private_Tour" done
# 0 page done
# "Full_Day_NO_SHOPPING_DMZ_Tour_starting_9_00AM" done
# 0 page done
# "Private_Palace_Photo_Shoot_in_Seoul_with_a_Photographer" done
# 0 page done
# "Modern_and_Contemporary_of_Seoul_tour" done
# 0 page done
# "Winter_8_days_Ski_Jeju_Busan_Mt_Seorak_Seoul_on_the_end_Nov_to_Jan" done
# 0 page done
# "Insadong_Gyeongbok_Palace_Hanok_Village_Gwangjang_Market_Korea_Day_Tour" done
# 0 page done
# "Korea_by_LocalGood_Morning_Seoul,_hidden_Alley_and_Korea_Craft_Wine_experience" done
# 0 page done
# 1 page done
# "Suwon_Hwaseong_Fortress_and_Korean_Folk_Village_Day_Tour_from_Seoul" done
# 0 page done
# "Korean_Palace_and_Temple_Tour_in_Seoul_Gyeongbokgung_Palace_and_Jogyesa_Temple" done
# 0 page done
# "Korean_Folk_Village" done
# 0 page done
# "History_and_Culture_Tour" done
# 0 page done
# 1 page done
# 2 page done
# 3 page done
# 4 page done
# "Gyeongbokgung_Palace_Hanbok_Rental_Experience_in_Seoul" done

# %%
review_all_tours.to_excel(f'./t_scraped/review_all_tours.xlsx')

# %% [markdown]
# 추가작업
# - 가격 등 기타 정보 수집
# - 엑셀 파일 통합 저장
